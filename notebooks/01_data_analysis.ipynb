# %%
# Out:
#   system:index      NDVI         VH        VV  soil_moisture  \
# 0   20200126_0  0.616043 -14.525705 -9.314484       0.232750
# 1   20200126_1  0.543127 -14.547543 -9.376667       0.239541
# 2   20200126_2  0.572490 -14.458326 -9.310692       0.239541
# 3   20200126_3  0.450533 -14.260935 -9.228480       0.239541
# 4   20200126_4  0.427533 -13.817124 -8.491948       0.239541
#
#                                                 .geo
# 0  {"geodesic":false,"type":"Point","coordinates"...
# 1  {"geodesic":false,"type":"Point","coordinates"...
# 2  {"geodesic":false,"type":"Point","coordinates"...
# 3  {"geodesic":false,"type":"Point","coordinates"...
# 4  {"geodesic":false,"type":"Point","coordinates"...
#
# Columns: Index(['system:index', 'NDVI', 'VH', 'VV', 'soil_moisture', '.geo'], dtype='object')
#
# Missing values:
#  system:index     0
# NDVI             0
# VH               0
# VV               0
# soil_moisture    0
# .geo             0
# dtype: int64
#
# Basic stats:
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/Raw/Kaveri_Delta_Soil_Moisture.csv")
print(df.head())
print("\nColumns:", df.columns)
print("\nMissing values:\n", df.isnull().sum())
print("\nBasic stats:\n", df.describe())
# Out:
#   system:index      NDVI         VH        VV  soil_moisture  \
# 0   20200126_0  0.616043 -14.525705 -9.314484       0.232750
# 1   20200126_1  0.543127 -14.547543 -9.376667       0.239541
# 2   20200126_2  0.572490 -14.458326 -9.310692       0.239541
# 3   20200126_3  0.450533 -14.260935 -9.228480       0.239541
# 4   20200126_4  0.427533 -13.817124 -8.491948       0.239541
#
#                                                 .geo
# 0  {"geodesic":false,"type":"Point","coordinates"...
# 1  {"geodesic":false,"type":"Point","coordinates"...
# 2  {"geodesic":false,"type":"Point","coordinates"...
# 3  {"geodesic":false,"type":"Point","coordinates"...
# 4  {"geodesic":false,"type":"Point","coordinates"...
#
# Columns: Index(['system:index', 'NDVI', 'VH', 'VV', 'soil_moisture', '.geo'], dtype='object')
#
# Missing values:
#  system:index     0
# NDVI             0
# VH               0
# VV               0
# soil_moisture    0
# .geo             0
# dtype: int64
#
# Basic stats:
# ...
